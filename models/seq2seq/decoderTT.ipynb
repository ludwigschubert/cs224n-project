# %%
from __future__ import print_function
from load_glove import *
import json
from collections import defaultdict
import numpy as np
import tensorflow as tf

# %%
GLOVE_LOC = '../../data/glove/glove.6B.50d.txt'
DATASET = '../../data/duc2004/data.json' #nips-abstract-title #squad #
INPUT_MAX = 150
OUTPUT_MAX = 15
VOCAB_MAX = 30000

GLV_RANGE = 0.5
LR_DECAY = 1000
LR_DECAY_AMOUNT = 0.9
starter_learning_rate = 1e-2
hs = 128
batch_size = 32
PRINT_EVERY = 25
TRAIN_KEEP_PROB = 0.5
TRAIN_EMBEDDING = True

# %%
words = glove2dict(GLOVE_LOC)
word_counter = defaultdict(int)
GLV_DIM = words['the'].shape[0]

def clean(text,clip_n=0):
    res = text.replace('<d>','').replace('<p>','').replace('<s>','').replace('</d>','').replace('</p>','').replace('</s>','')
    
    r2 = []
    for word in res.split():
        if word not in words:
            words[word] = np.array([random.uniform(-GLV_RANGE, GLV_RANGE) for i in range(GLV_DIM)])
    for word in res.split():
        word_counter[word] += 1
    if clip_n > 0:
        return ' '.join(res.split()[:clip_n])
    else:
        return res

# %%
with open(DATASET) as fp:
    data = json.load(fp)
    train = [x for x in data if x['set'] == 'train']
    dev = [x for x in data if x['set'] == 'dev']
    test = [x for x in data if x['set'] == 'test']

    train = [(clean(x['data'],INPUT_MAX),clean(x['label'][0],OUTPUT_MAX)) for x in train]
    dev = [(clean(x['data'],INPUT_MAX),clean(x['label'][0],OUTPUT_MAX)) for x in dev]
    test = [(clean(x['data'],INPUT_MAX),clean(x['label'][0],OUTPUT_MAX)) for x in test]

    valid_words = (sorted([(v,k) for k,v in word_counter.items()])[::-1])
    #print len(valid_words)
    valid_words = [x[1] for x in valid_words[:VOCAB_MAX]] + ['<EOS>','<PAD>','<UNK>','<SOS>']

    initial_matrix = np.array([words[x] for x in valid_words])
    def sent_to_idxs(sentence):
        base =  [valid_words.index(word) for word in sentence.split()]
        sen_len = len(base)
        base =  [valid_words.index('<SOS>')] + base# + [valid_words.index('<EOS>')]
        pad_word = (OUTPUT_MAX-sen_len)
        base = base + pad_word*[valid_words.index('<EOS>')]
        return base,(sen_len,pad_word)
    def sent_to_idxs_nopad(sentence):
        base =  [valid_words.index(word) for word in sentence.split()]
        return base
    train_x = [sent_to_idxs_nopad(x[0]) for x in train]
    train_y = [sent_to_idxs(x[1])[0] for x in train]
    train_len = [sent_to_idxs(x[1])[1] for x in train]

    dev_x = [sent_to_idxs_nopad(x[0]) for x in dev]
    dev_y = [sent_to_idxs(x[1])[0] for x in dev]
    dev_len = [sent_to_idxs(x[1])[1] for x in dev]

    test_x = [sent_to_idxs_nopad(x[0]) for x in test]
    test_y = [sent_to_idxs(x[1])[0] for x in test]
    test_len = [sent_to_idxs(x[1])[1] for x in test]

    
#train_x[0],train_y[0]

# %%
tf.reset_default_graph()
global_step = tf.Variable(0, trainable=False)
VOCAB_SIZE = len(valid_words)
learning_rate = tf.train.exponential_decay(starter_learning_rate, global_step,LR_DECAY, LR_DECAY_AMOUNT, staircase=True)

input_placeholder = tf.placeholder(tf.int32)
mask_placeholder = tf.placeholder(tf.float32,(None,OUTPUT_MAX))
labels_placeholder = tf.placeholder(tf.int32,(None,OUTPUT_MAX+1))
dropout_rate = tf.placeholder(tf.float32,())

embedding = tf.Variable(initial_matrix,dtype=tf.float32,trainable=TRAIN_EMBEDDING)
input_embed = tf.nn.embedding_lookup(embedding,input_placeholder)
input_summed= tf.reduce_mean(input_embed,1)
print(input_summed.get_shape())


hh0 = tf.get_variable("hh0", shape=[GLV_DIM,hs], initializer=tf.contrib.layers.xavier_initializer(),dtype=tf.float32) 
hb0 = tf.Variable(tf.constant(0.0, shape=[hs],dtype=tf.float32))
cell = tf.contrib.rnn.GRUCell(hs)

looked_up = tf.nn.embedding_lookup(embedding,labels_placeholder)
x = tf.reshape(looked_up,[-1,OUTPUT_MAX+1,GLV_DIM])

U = tf.get_variable("U", shape=(hs,VOCAB_SIZE), initializer=tf.contrib.layers.xavier_initializer())
b2 = tf.get_variable("b2", shape=(VOCAB_SIZE,), initializer=tf.constant_initializer(0.0))
state = tf.matmul(input_summed,hh0) + hb0

outputs, states = tf.nn.dynamic_rnn(cell, x, initial_state=state,dtype=tf.float32)
outputs_batchword = tf.reshape(outputs[:,:OUTPUT_MAX,:],[-1,hs])
out_drop = tf.nn.dropout(outputs_batchword,dropout_rate)
pred_batchword = tf.matmul(out_drop,U) + b2
preds = tf.reshape(pred_batchword,[-1,OUTPUT_MAX,VOCAB_SIZE])

ce = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=preds,labels=labels_placeholder[:,1:])
loss = tf.reduce_mean(mask_placeholder * ce)
tf.summary.scalar('loss', loss)

optimizer = tf.train.AdamOptimizer(learning_rate)
gvs = optimizer.compute_gradients(loss)
capped_gvs = [((tf.clip_by_value(grad, -1., 1.) if grad != None else None), var)  for grad, var in gvs]
train_step = optimizer.apply_gradients(capped_gvs,global_step=global_step)
# Out:
# <unknown>

# %%
def sample(context_vector):
    sentence = []
    for i in xrange(OUTPUT_MAX):
        x = sent_to_idxs(' '.join(sentence))[0]
        #print(x)
        feed_dict = {
            input_placeholder: np.array(context_vector).reshape([1,-1]),
            labels_placeholder: np.array(x).reshape([1,-1]),
            dropout_rate: 1.0
            #mask_placeholder: None
        }
        probs = np.squeeze(preds.eval(feed_dict=feed_dict))
        new_word = valid_words[np.argmax(probs[i,:])]
        if new_word != '<EOS>':
            sentence.append(new_word)
        else:
            break
    return ' '.join(sentence)
with tf.Session() as sess:
    merged = tf.summary.merge_all()
    #summary_writer = tf.summary.FileWriter('./train', sess.graph)
    #saver =  tf.train.Saver()
    sess.run(tf.global_variables_initializer())
    data_size = len(train_x)
    for i in range(data_size*10):
        # cost, label,mask,data_size
        start_idx = (i*batch_size)%data_size
        end_idx = start_idx+batch_size
        #print(train_len[start_idx:end_idx])
        mask = np.array([np.array([1.0]*x[0] + [0.0]*x[1]) for x in train_len[start_idx:end_idx]])
        #print(mask.shape)
        #print(np.array(train_y[start_idx:end_idx]).shape)
        #print(np.array(train_x[start_idx:end_idx]).shape)
        train_sizes = [len(x) for x in train_x[start_idx:end_idx]]
        train_mat = np.zeros(shape=(len(train_sizes),max(train_sizes)))
        for idx,row in enumerate(train_x[start_idx:end_idx]):
            train_mat[idx,:train_sizes[idx]] = np.array(row)
        feed_dict = {
            input_placeholder: train_mat,
            labels_placeholder: train_y[start_idx:end_idx],
            mask_placeholder: mask,
            dropout_rate: TRAIN_KEEP_PROB
        }
        _, bl, summary = sess.run([train_step, loss, merged], feed_dict=feed_dict)
        #summary_writer.add_summary(summary, i)
        if i % PRINT_EVERY == 0:
            print(i,bl)
            print('TRAIN_SAMPLE: ',sample(train_x[start_idx]))
            print('TRAIN_LABEL: ',' '.join([x for x in [valid_words[x] for x in train_y[start_idx]] if x not in ['<EOS>','<SOS>']]))
            print()
            index = int(random.random()*10)
            print('DEV_SAMPLE: ',sample(dev_x[index]))
            print('DEV_LABEL: ',' '.join([x for x in [valid_words[x] for x in dev_y[index]] if x not in ['<EOS>','<SOS>']]))
            print('\n')
        #    saver.save(sess, 'model-checkpoint-', global_step=i)
        #    summary_writer.flush()
# Out:
# 0 6.74146
# TRAIN_SAMPLE:  cambodian cambodian to of of of of of of of of of of of of
# TRAIN_LABEL:  cambodian government rejects opposition 's call for talks abroad
#
# DEV_SAMPLE:  cambodian cambodian to of of of of of of of of of of of of
# DEV_LABEL:  cambodian king announces coalition government with hun sen as sole premier
#
#
# 25 5.30019
# TRAIN_SAMPLE:  . of of of of of of of of of of of of of of
# TRAIN_LABEL:  hurricane mitch weakens after widespread destruction in honduras
#
# DEV_SAMPLE:  of of of of of of of of of of of of of of of
# DEV_LABEL:  jet shot down by congo rebels possibly military , possibly civil
#
#
# 50 4.72534
# TRAIN_SAMPLE:  china to of of of of of . . . . . . . .
# TRAIN_LABEL:  ex-prime minister thatcher hosted pinochet at home before his arrest
#
# DEV_SAMPLE:  china to to to to . . . . . . . . . .
# DEV_LABEL:  efforts to form chinese opposition party bring arrest
#
#
# 75 3.76889
# TRAIN_SAMPLE:  china of of of of of of of of of of of of of of
# TRAIN_LABEL:  bangladeshi police arrest journalists for promoting islamic revolution
#
# DEV_SAMPLE:  china 's to to to to to to to to to to to to to
# DEV_LABEL:  hun sen , prince ranariddh share power in new coalition cambodian government
#
#
# 100 3.1392
# TRAIN_SAMPLE:  $ 800 800 stake of pay during lockout series series series series series series series
# TRAIN_LABEL:  $ 800 million at stake in arbitrator 's decision on pay during lockout
#
# DEV_SAMPLE:  china 's arrest to new to new to new . new . new . new
# DEV_LABEL:  hun sen , prince ranariddh share power in new coalition cambodian government
#
#
# 125 2.30882
# TRAIN_SAMPLE:  congo rebels rebels rebels rebels rebels of congo rebels . east timor . east timor
# TRAIN_LABEL:  congo rebels use internet to rally international support
#
# DEV_SAMPLE:  congo rebels rebels rebels rebels rebels of congo rebels . east timor . east timor
# DEV_LABEL:  congo rebels use internet to rally international support
#
#
# 150 1.73785
# TRAIN_SAMPLE:  malaysian prime minister seeks replacement for new deputy prime minister minister minister minister minister minister
# TRAIN_LABEL:  malaysian party seeks replacement for arrested deputy prime minister
#
# DEV_SAMPLE:  u.n. korea wants n. korea impaired to see possible nuclear site . possible site .
# DEV_LABEL:  red cross reports severe famine and starvation in north korea
#
#
# 175 1.30468
# TRAIN_SAMPLE:  asia-pacific economic economic economic economic economic economic economic economic economic economic economic economic economic economic
# TRAIN_LABEL:  malaysian capital controls an issue at economic summit
#
# DEV_SAMPLE:  n. korea wants to see possible of possible of possible of possible of possible of
# DEV_LABEL:  red cross reports severe famine and starvation in north korea
#
#
# 200 1.05802
# TRAIN_SAMPLE:  letter reaffirms qatar , to be be be be be be be be be be
# TRAIN_LABEL:  palestinian suicide bomber learned islamic jihad doctrine in israeli prison
#
# DEV_SAMPLE:  ecevit fails to quit ; will be be be be be be be be be
# DEV_LABEL:  cambodian party rejects government offer to share legislative office
#
#
# 225 0.855944
# TRAIN_SAMPLE:  malaysian prime minister minister minister minister minister minister minister minister minister minister minister minister minister
# TRAIN_LABEL:  malaysia 's trade minister discounts unrest over arrest of dissident
#
# DEV_SAMPLE:  congo rebels control third of kindu , but outcome not clear of congo dispute .
# DEV_LABEL:  jet shot down by congo rebels possibly military , possibly civil
#
#
# 250 0.708467
# TRAIN_SAMPLE:  u.s. envoy holbrooke gives last minute warning to get milosevic of kosovo or face nato
# TRAIN_LABEL:  u.s. envoy holbrooke gives last minute warning to milosevic on kosovo
#
# DEV_SAMPLE:  china exiles rights campaigner to u.s. to soften trial of noted dissident party rule against
# DEV_LABEL:  efforts to form chinese opposition party bring arrest
#
#
# 275 0.64058
# TRAIN_SAMPLE:  u.s. sends illegal north korea sends largest team in thailand . north korea arrives in
# TRAIN_LABEL:  china sends illegal north korean settlers back to famine at home
#
# DEV_SAMPLE:  israel suspends ratification to wye agreement to wye agreement to wye agreement to wye agreement
# DEV_LABEL:  israel postpones vote on wye pact until palestinians act against terrorists
#
#
# 300 0.518272
# TRAIN_SAMPLE:  saudis considering small asian games team in response to kuwaiti plea . kuwaiti plea .
# TRAIN_LABEL:  saudis considering small asian games team in response to kuwaiti plea
#
# DEV_SAMPLE:  cambodian government leader of lebanon 's support of lebanon 's president to end apartheid on
# DEV_LABEL:  hun sen , prince ranariddh share power in new coalition cambodian government
#
#
# 325 0.371497
# TRAIN_SAMPLE:  china democracy party leader of china democracy party accused of colluding with foreign enemies of
# TRAIN_LABEL:  leader of china democracy party accused of colluding with foreign enemies
#
# DEV_SAMPLE:  organizing committee assures that asian games complex will be ready for help to asian games
# DEV_LABEL:  thais question reason for saudi withdrawal from asian games
#
#
# 350 0.368021
# TRAIN_SAMPLE:  election results results on budget mess basis for livingston-gingrich conflict . clinton to quit .
# TRAIN_LABEL:  livingston gains support in challenge to gingrich for house speaker
#
# DEV_SAMPLE:  ecevit fails ; turkish president to be next president of lebanon 's president to be
# DEV_LABEL:  cambodian party rejects government offer to share legislative office
#
#
# 375 0.293663
# TRAIN_SAMPLE:  microsoft argues aol-netscape deal would undermine government 's case case against microsoft would give case
# TRAIN_LABEL:  microsoft argues aol-netscape deal would undermine government 's case
#
# DEV_SAMPLE:  ecevit fails ; turkish president to be next president of lebanon 's president to be
# DEV_LABEL:  cambodian party rejects government offer to share legislative office
#
#
# 400 0.288101
# TRAIN_SAMPLE:  russian financial crisis now in the mail as post office goes broke post office goes
# TRAIN_LABEL:  russian financial crisis now in the mail as post office goes broke
#
# DEV_SAMPLE:  cambodian government control of lebanon 's president to next government . lebanon 's president to
# DEV_LABEL:  hun sen , prince ranariddh share power in new coalition cambodian government
#
#
# 425 0.220788
# TRAIN_SAMPLE:  jordan joins egypt and iran offering help to resolve turkey-syria dispute . egypt in mediation
# TRAIN_LABEL:  iran offers to join egypt in mediation of turkey-syria dispute
#
# DEV_SAMPLE:  mitch weakens after widespread destruction in honduras , hurricane mitch killed . hurricane mitch killed
# DEV_LABEL:  nicaraguan vice president reports thousands buried in country
#
#
# 450 0.194039
# TRAIN_SAMPLE:  37 of 115 yachts forced out of sydney-to-hobart race . maxi sayonara leads of sydney-to-hobart
# TRAIN_LABEL:  37 of 115 yachts forced out of sydney-to-hobart race
#
# DEV_SAMPLE:  ioc president samaranch pledges expulsion of any bribe-taking members , but hero to appoint ready
# DEV_LABEL:  thais question reason for saudi withdrawal from asian games
#
#
# 475 0.223539
# TRAIN_SAMPLE:  russian economic collapse affects plans for international space station space station economic station economic collapse
# TRAIN_LABEL:  russian economic collapse affects plans for international space station
#
# DEV_SAMPLE:  congo rebels use internet to rally international support of indonesian troops bound for east timor
# DEV_LABEL:  congo rebels use internet to rally international support
#
#
# 500 0.213272
# TRAIN_SAMPLE:  inflation rate drops in nations about to adopt euro euro euro euro euro euro euro
# TRAIN_LABEL:  inflation rate drops in nations about to adopt euro
#
# DEV_SAMPLE:  u.s. and britain vow to punish pan am bombers at 10 year memorial of event
# DEV_LABEL:  nicaraguan vice president reports thousands buried in country
#
#
# 525 0.173868
# TRAIN_SAMPLE:  east timorese exiles report indonesian troops ' attack on civilians . civilians . civilians .
# TRAIN_LABEL:  east timorese exiles report indonesian troops ' attack on civilians
#
# DEV_SAMPLE:  organizing committee assures that asian games complex will be ready for meeting about lockerbie bombing
# DEV_LABEL:  thais question reason for saudi withdrawal from asian games
#
#
# 550 0.192212
# TRAIN_SAMPLE:  nobel laureate saramago says other portuguese writers deserved award award award award award award prize
# TRAIN_LABEL:  nobel laureate saramago says other portuguese writers deserved award
#
# DEV_SAMPLE:  organizing committee assures that asian games complex will be ready for help to asian games
# DEV_LABEL:  thais question reason for saudi withdrawal from asian games
#
#
# 575 0.249091
# TRAIN_SAMPLE:  sharon appointment seen as `` bullet of mercy '' to peace process to peace process
# TRAIN_LABEL:  sharon appointment seen as `` bullet of mercy '' to peace process
#
# DEV_SAMPLE:  israel suspends ratification to wye agreement to agreement of wye agreement of wye agreement after
# DEV_LABEL:  israel postpones vote on wye pact until palestinians act against terrorists
#
#
# 600 0.249602
# TRAIN_SAMPLE:  ioc rules limit any gifts and benefits to $ 150 per person person person person
# TRAIN_LABEL:  ioc rules limit any gifts and benefits to $ 150 per person
#
# DEV_SAMPLE:  ecevit fails ; turkish president to ask another or wait to appoint cabinet . new
# DEV_LABEL:  cambodian party rejects government offer to share legislative office
#
#
# 625 0.213644
# TRAIN_SAMPLE:  palestinians celebrate opening of gaza international airport to open . who will be first arrival
# TRAIN_LABEL:  palestinians celebrate opening of gaza international airport
#
# DEV_SAMPLE:  china exiles rights campaigner to u.s. to soften trial of noted dissident appeals conviction against
# DEV_LABEL:  efforts to form chinese opposition party bring arrest
#
#
# 650 0.200058
# TRAIN_SAMPLE:  annan to go to libya for meeting about lockerbie bombing and un sanctions . lockerbie
# TRAIN_LABEL:  annan to go to libya for meeting about lockerbie bombing and un sanctions .
#
# DEV_SAMPLE:  honduras , belize in mexico brace for category 5 hurricane mitch killed 9,000 at 393
# DEV_LABEL:  nicaraguan vice president reports thousands buried in country
#
#
# 675 0.148212
# TRAIN_SAMPLE:  greek media and officials oppose extradition of ocalan to turkey . denies harboring of ocalan
# TRAIN_LABEL:  greek media and officials oppose extradition of ocalan to turkey .
#
# DEV_SAMPLE:  cambodian opposition leader doubts safety guaranty of government they control of lebanon 's president will
# DEV_LABEL:  hun sen , prince ranariddh share power in new coalition cambodian government
#
#
# 700 0.15292
# TRAIN_SAMPLE:  exxon-mobil talks continue ; would be largest oil company ; oil stocks rise . unity
# TRAIN_LABEL:  exxon-mobil talks continue ; would be largest oil company ; oil stocks rise .
#
# DEV_SAMPLE:  israel suspends ratification of wye agreement after hamas bomb attack on west bank pullback market
# DEV_LABEL:  israel postpones vote on wye pact until palestinians act against terrorists
#
#
# 725 0.119185
# TRAIN_SAMPLE:  house moves to impeach clinton for perjury ; calls on senate to try him .
# TRAIN_LABEL:  house moves to impeach clinton for perjury ; calls on senate to try him .
#
# DEV_SAMPLE:  cambodian government rejects lebanon 's support of lebanon 's but lebanon 's but lebanon 's
# DEV_LABEL:  hun sen , prince ranariddh share power in new coalition cambodian government
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-79b10fd6effb> in <module>()
#      42             dropout_rate: TRAIN_KEEP_PROB
#      43         }
# ---> 44         _, bl, summary = sess.run([train_step, loss, merged], feed_dict=feed_dict)
#      45         #summary_writer.add_summary(summary, i)
#      46         if i % PRINT_EVERY == 0:
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     767     try:
#     768       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 769                          run_metadata_ptr)
#     770       if run_metadata:
#     771         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     965     if final_fetches or final_targets:
#     966       results = self._do_run(handle, final_targets, final_fetches,
# --> 967                              feed_dict_string, options, run_metadata)
#     968     else:
#     969       results = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1015     if handle is None:
#    1016       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1017                            target_list, options, run_metadata)
#    1018     else:
#    1019       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1022   def _do_call(self, fn, *args):
#    1023     try:
# -> 1024       return fn(*args)
#    1025     except errors.OpError as e:
#    1026       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1004         return tf_session.TF_Run(session, options,
#    1005                                  feed_dict, fetch_list, target_list,
# -> 1006                                  status, run_metadata)
#    1007
#    1008     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
