# %%
from __future__ import print_function
from load_glove import *
import json
from collections import defaultdict
import numpy as np
import tensorflow as tf

# %%
GLOVE_LOC = '../../data/glove/glove.6B.50d.txt'
DATASET = '../../data/squad/data.json' #nips-abstract-title #squad #
INPUT_MAX = 150
OUTPUT_MAX = 15
VOCAB_MAX = 30000

GLV_RANGE = 0.5
LR_DECAY = 1000
LR_DECAY_AMOUNT = 0.9
starter_learning_rate = 1e-2
hs = 128

batch_size = 32
PRINT_EVERY = 25
TRAIN_KEEP_PROB = 0.5
TRAIN_EMBEDDING = False
USE_CNN = True
KERNEL_SIZE = 7

# %%
words = glove2dict(GLOVE_LOC)
word_counter = defaultdict(int)
GLV_DIM = words['the'].shape[0]

def clean(text,clip_n=0):
    res = text.replace('<d>','').replace('<p>','').replace('<s>','').replace('</d>','').replace('</p>','').replace('</s>','')
    
    r2 = []
    for word in res.split():
        if word not in words:
            words[word] = np.array([random.uniform(-GLV_RANGE, GLV_RANGE) for i in range(GLV_DIM)])
    for word in res.split():
        word_counter[word] += 1
    if clip_n > 0:
        return ' '.join(res.split()[:clip_n])
    else:
        return res

# %%
from collections import defaultdict
with open(DATASET) as fp:
    data = json.load(fp)
    train = [x for x in data if x['set'] == 'train']
    dev = [x for x in data if x['set'] == 'dev']
    test = [x for x in data if x['set'] == 'test']

    train = [(clean(x['data'],INPUT_MAX),clean(x['label'][0],OUTPUT_MAX)) for x in train]
    dev = [(clean(x['data'],INPUT_MAX),clean(x['label'][0],OUTPUT_MAX)) for x in dev]
    test = [(clean(x['data'],INPUT_MAX),clean(x['label'][0],OUTPUT_MAX)) for x in test]

    valid_words = (sorted([(v,k) for k,v in word_counter.items()])[::-1])
    print(len(valid_words))
    valid_words = [x[1] for x in valid_words[:VOCAB_MAX]] + ['<EOS>','<PAD>','<UNK>','<SOS>']
    unk_idx = valid_words.index('<UNK>')
    vwd = defaultdict(lambda : unk_idx)
    for idx,word in enumerate(valid_words):
        vwd[word] = idx

    initial_matrix = np.array([words[x] for x in valid_words])
    def sent_to_idxs(sentence):
        base =  [vwd[word] for word in sentence.split()]
        sen_len = len(base)
        base =  [vwd['<SOS>']] + base# + [valid_words.index('<EOS>')]
        pad_word = (OUTPUT_MAX-sen_len)
        base = base + pad_word*[vwd['<EOS>']]
        return base,(sen_len,pad_word)
    def sent_to_idxs_nopad(sentence):
        base =  [vwd[word] for word in sentence.split()]
        return base
    train_x = [sent_to_idxs_nopad(x[0]) for x in train]
    train_y = [sent_to_idxs(x[1])[0] for x in train]
    train_len = [sent_to_idxs(x[1])[1] for x in train]

    dev_x = [sent_to_idxs_nopad(x[0]) for x in dev]
    dev_y = [sent_to_idxs(x[1])[0] for x in dev]
    dev_len = [sent_to_idxs(x[1])[1] for x in dev]

    test_x = [sent_to_idxs_nopad(x[0]) for x in test]
    test_y = [sent_to_idxs(x[1])[0] for x in test]
    test_len = [sent_to_idxs(x[1])[1] for x in test]

    
#train_x[0],train_y[0]
# Out:
# 59691

# %%
tf.reset_default_graph()
global_step = tf.Variable(0, trainable=False)
VOCAB_SIZE = len(valid_words)
learning_rate = tf.train.exponential_decay(starter_learning_rate, global_step,LR_DECAY, LR_DECAY_AMOUNT, staircase=True)

input_placeholder = tf.placeholder(tf.int32)
mask_placeholder = tf.placeholder(tf.float32,(None,OUTPUT_MAX))
labels_placeholder = tf.placeholder(tf.int32,(None,OUTPUT_MAX+1))
dropout_rate = tf.placeholder(tf.float32,())
embedding = tf.Variable(initial_matrix,dtype=tf.float32,trainable=TRAIN_EMBEDDING)
input_embed = tf.nn.embedding_lookup(embedding,input_placeholder)
if USE_CNN:
    #img_input = tf.expand_dims(input_embed,2)
    W1 = tf.get_variable("W1", shape=[KERNEL_SIZE,GLV_DIM,hs], initializer=tf.contrib.layers.xavier_initializer())
    b1 = tf.Variable(tf.constant(0.0, shape=[hs]))
    W2 = tf.get_variable("W2", shape=[1,hs,hs], initializer=tf.contrib.layers.xavier_initializer())
    b2 = tf.Variable(tf.constant(0.0, shape=[hs]))
    #print(input_embed.get_shape())
    h_conv1 = tf.nn.tanh(tf.nn.conv1d(input_embed, W1, stride=1, padding='SAME') + b1)
    h_state =  tf.nn.conv1d(h_conv1, W2, stride=1, padding='SAME') + b2
    #h_vec = tf.squeeze(h_state)
    state = tf.reduce_max(h_state,1)
    #print(state.get_shape())
    
else:
    input_summed= tf.reduce_mean(input_embed,1)
    
    hh0 = tf.get_variable("hh0", shape=[GLV_DIM,hs], initializer=tf.contrib.layers.xavier_initializer(),dtype=tf.float32) 
    hb0 = tf.Variable(tf.constant(0.0, shape=[hs],dtype=tf.float32))
    #print(input_summed.get_shape())


cell = tf.contrib.rnn.GRUCell(hs)

looked_up = tf.nn.embedding_lookup(embedding,labels_placeholder)
x = tf.reshape(looked_up,[-1,OUTPUT_MAX+1,GLV_DIM])

U = tf.get_variable("U", shape=(hs,VOCAB_SIZE), initializer=tf.contrib.layers.xavier_initializer())
b2 = tf.get_variable("b2", shape=(VOCAB_SIZE,), initializer=tf.constant_initializer(0.0))
if USE_CNN:
    pass
else:
    state = tf.matmul(input_summed,hh0) + hb0

outputs, states = tf.nn.dynamic_rnn(cell, x, initial_state=state,dtype=tf.float32)
outputs_batchword = tf.reshape(outputs[:,:OUTPUT_MAX,:],[-1,hs])
out_drop = tf.nn.dropout(outputs_batchword,dropout_rate)
pred_batchword = tf.matmul(out_drop,U) + b2
preds = tf.reshape(pred_batchword,[-1,OUTPUT_MAX,VOCAB_SIZE])

ce = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=preds,labels=labels_placeholder[:,1:])
loss = tf.reduce_mean(mask_placeholder * ce)
tf.summary.scalar('loss', loss)

optimizer = tf.train.AdamOptimizer(learning_rate)
gvs = optimizer.compute_gradients(loss)
capped_gvs = [((tf.clip_by_value(grad, -1., 1.) if grad != None else None), var)  for grad, var in gvs]
train_step = optimizer.apply_gradients(capped_gvs,global_step=global_step)

# %%
def sample(context_vector):
    sentence = []
    for i in xrange(OUTPUT_MAX):
        x = sent_to_idxs(' '.join(sentence))[0]
        #print(x)
        feed_dict = {
            input_placeholder: np.array(context_vector).reshape([1,-1]),
            labels_placeholder: np.array(x).reshape([1,-1]),
            dropout_rate: 1.0
            #mask_placeholder: None
        }
        probs = np.squeeze(preds.eval(feed_dict=feed_dict))
        new_word = valid_words[np.argmax(probs[i,:])]
        if new_word != '<EOS>':
            sentence.append(new_word)
        else:
            break
    return ' '.join(sentence)
with tf.Session() as sess:
    merged = tf.summary.merge_all()
    #summary_writer = tf.summary.FileWriter('./train', sess.graph)
    #saver =  tf.train.Saver()
    sess.run(tf.global_variables_initializer())
    data_size = len(train_x)
    for i in range(data_size*10):
        # cost, label,mask,data_size
        start_idx = (i*batch_size)%data_size
        end_idx = start_idx+batch_size
        #print(train_len[start_idx:end_idx])
        mask = np.array([np.array([1.0]*x[0] + [0.0]*x[1]) for x in train_len[start_idx:end_idx]])
        #print(mask.shape)
        #print(np.array(train_y[start_idx:end_idx]).shape)
        #print(np.array(train_x[start_idx:end_idx]).shape)
        train_sizes = [len(x) for x in train_x[start_idx:end_idx]]
        train_mat = np.zeros(shape=(len(train_sizes),max(train_sizes)))
        for idx,row in enumerate(train_x[start_idx:end_idx]):
            train_mat[idx,:train_sizes[idx]] = np.array(row)
        feed_dict = {
            input_placeholder: train_mat,
            labels_placeholder: train_y[start_idx:end_idx],
            mask_placeholder: mask,
            dropout_rate: TRAIN_KEEP_PROB
        }
        _, bl, summary = sess.run([train_step, loss, merged], feed_dict=feed_dict)
        #summary_writer.add_summary(summary, i)
        if i % PRINT_EVERY == 0:
            print(i,bl)
            print('TRAIN_SAMPLE: ',sample(train_x[start_idx]))
            print('TRAIN_LABEL: ',' '.join([x for x in [valid_words[x] for x in train_y[start_idx]] if x not in ['<EOS>','<SOS>']]))
            print()
            index = int(random.random()*10)
            #print('DEV_SAMPLE: ',sample(dev_x[index]))
            #print('DEV_LABEL: ',' '.join([x for x in [valid_words[x] for x in dev_y[index]] if x not in ['<EOS>','<SOS>']]))
            print('\n')
        #    saver.save(sess, 'model-checkpoint-', global_step=i)
        #    summary_writer.flush()
# Out:
# 0 8.46632
# TRAIN_SAMPLE:  john john john the the the the the the the the dame . . .
# TRAIN_LABEL:  to saint <UNK> <UNK> did the virgin mary allegedly appear in 1858 in lourdes france
#
#
#
# 25 5.98516
# TRAIN_SAMPLE:  the the the the the the the the the . . . . . .
# TRAIN_LABEL:  <UNK> approval is required for the president 's appointees to take office .
#
#
#
# 50 5.77212
# TRAIN_SAMPLE:  the the the the the the the . . . . . . . .
# TRAIN_LABEL:  the united nations formulates multiple regional divisions as is convenient for its various operations .
#
#
#
# 75 6.52267
# TRAIN_SAMPLE:  1969 the the of the of the of the of the . . . .
# TRAIN_LABEL:  emperor haile selassie dissolved the eritrean parliament in 1962 .
#
#
#
# 100 5.78305
# TRAIN_SAMPLE:  what was the the of the the of the of the of the of the
# TRAIN_LABEL:  the aztecs originally built mexico city .
#
#
#
# 125 5.14145
# TRAIN_SAMPLE:  the of the first of the most of the most of the of . .
# TRAIN_LABEL:  hitler was planning an invasion of the soviet union .
#
#
#
# 150 6.09531
# TRAIN_SAMPLE:  what is the first of the of of the of of the of . .
# TRAIN_LABEL:  alberto valderrama , jesus rengel , ricardo sandoval , saul vera , and cristobal soto
#
#
#
# 175 5.28543
# TRAIN_SAMPLE:  what was the of of the of of the of of the of of the
# TRAIN_LABEL:  the german empire did the bolsheviks make peace with .
#
#
#
# 200 5.35512
# TRAIN_SAMPLE:  the of the first of the first of the first of the first of the
# TRAIN_LABEL:  robert b. anderson did eisenhower want as his 1956 running mate .
#
#
#
# 225 6.35826
# TRAIN_SAMPLE:  the first of the first of the first of the first of the first of
# TRAIN_LABEL:  george soros commented that the super-boom got out of hand when products became so complicated
#
#
#
# 250 4.88582
# TRAIN_SAMPLE:  what is the name of the <UNK> of the <UNK> . . . . .
# TRAIN_LABEL:  mieszko i of poland established an elite knightly retinue .
#
#
#
# 275 6.27448
# TRAIN_SAMPLE:  the united of the first of the first of the of of the of of
# TRAIN_LABEL:  steve jobs admitted that apple was late to the party with writable cd technology .
#
#
#
# 300 5.81164
# TRAIN_SAMPLE:  general general of the first of the palace of the palace of the palace of
# TRAIN_LABEL:  the pentagon initially opposed general macarthur 's landing plan .
#
#
#
# 325 4.98654
# TRAIN_SAMPLE:  sultan was the first of the british of the british of the british of the
# TRAIN_LABEL:  sir john burgoyne was the engineer adviser .
#
#
#
# 350 5.43221
# TRAIN_SAMPLE:  the governor of the governor of the governor of the governor of the governor of
# TRAIN_LABEL:  france overthrew bokassa after this incident .
#
#
#
# 375 5.56882
# TRAIN_SAMPLE:  the british of the <UNK> of the <UNK> of the <UNK> . . . .
# TRAIN_LABEL:  the forest service , and either the fws or the nmfs reviews exemption considerations before
#
#
#
# 400 4.39646
# TRAIN_SAMPLE:  the soviet union did the first of the battle . the battle . the battle
# TRAIN_LABEL:  most protestants ( and most jews ) supported the ban against government aid to religious
#
#
#
# 425 4.54155
# TRAIN_SAMPLE:  what is the name of the american of the american of the american of the
# TRAIN_LABEL:  ryan seacrest was the host of american idol in its fourteenth season .
#
#
#
# 450 5.07107
# TRAIN_SAMPLE:  the united of the abbey of the abbey . the abbey . the abbey .
# TRAIN_LABEL:  beethoven is described as a founder of the romantic era .
#
#
#
# 475 5.1218
# TRAIN_SAMPLE:  the united of the united of the united of the united of the united of
# TRAIN_LABEL:  unix and unix-like systems , and <UNK> systems adopted this practice from multics .
#
#
#
# 500 5.94301
# TRAIN_SAMPLE:  the united was the first person of the <UNK> of the <UNK> of the <UNK>
# TRAIN_LABEL:  mr. thomas samuel hood purchased a plot of land in the name of the english
#
#
#
# 525 5.29224
# TRAIN_SAMPLE:  the sun <UNK> was the first person of the sun of the yale of the
# TRAIN_LABEL:  with <UNK> did paul vi celebrate surviving persecution in other countries .
#
#
#
# 550 4.50445
# TRAIN_SAMPLE:  what is the name of the <UNK> of the <UNK> of the <UNK> . the
# TRAIN_LABEL:  what <UNK> region did the east india company get control over after the carnatic wars
#
#
#
# 575 4.88941
# TRAIN_SAMPLE:  the <UNK> was the first <UNK> . the first of the <UNK> . the first
# TRAIN_LABEL:  mycenaean greek traders did the first wave of greek settlement consist of .
#
#
#
# 600 4.95257
# TRAIN_SAMPLE:  the first qing of the first 18th century . the first 18th century . the
# TRAIN_LABEL:  zeng guofan created a new type of army to thwart the taiping rebels .
#
#
#
# 625 5.60571
# TRAIN_SAMPLE:  the of the name of the name of the name of the name of the
# TRAIN_LABEL:  under <UNK> did the western part of umayyad caliphate 's empire gain its independence .
#
#
#
# 650 4.59177
# TRAIN_SAMPLE:  along with the arena of the city of the city . the city . the
# TRAIN_LABEL:  less and less new music fits their bill have hot ac format radio stations had
#
#
#
# 675 5.00008
# TRAIN_SAMPLE:  the houston was the first single of the single of the single . . .
# TRAIN_LABEL:  michael c. graham described the concept of a continuum of intensity .
#
#
#
# 700 4.47455
# TRAIN_SAMPLE:  abu bin was the first person of the first <UNK> . . . . .
# TRAIN_LABEL:  agathocles of syracuse was the leading figure in sicily during the hellenistic period .
#
#
#
# 725 4.68692
# TRAIN_SAMPLE:  the british states states states states states states states states states states states states states
# TRAIN_LABEL:  flavio <UNK> was the author of `` decades of history from the deterioration of the
#
#
#
# 750 4.28033
# TRAIN_SAMPLE:  the soviet union was the first baptist of the crucifixion . . . . .
# TRAIN_LABEL:  the subsequent reforms were coined as `` doma del reino de galicia '' by jeronimo
#
#
#
# 775 4.87474
# TRAIN_SAMPLE:  the <UNK> was the first the first the of the first of the first of
# TRAIN_LABEL:  berkeley did hegel see as a subjective idealist .
#
#
#
# 800 5.01226
# TRAIN_SAMPLE:  the united states states states states states states states states states states states states states
# TRAIN_LABEL:  lance barr designed the snes controllers .
#
#
#
# 825 4.36736
# TRAIN_SAMPLE:  link of the <UNK> of the <UNK> of the city of the city of the
# TRAIN_LABEL:  the london fire brigade helped the <UNK> simulate rain while shooting in london .
#
#
#
# 850 4.60059
# TRAIN_SAMPLE:  the canadian company bought the bbc . . the plymouth . the film . .
# TRAIN_LABEL:  what was the name of the governor isaac pyke suggested relocating the population of saint
#
#
#
# 875 4.53229
# TRAIN_SAMPLE:  sir thomson invented the computer of the times . the times . the times .
# TRAIN_LABEL:  the united states declared war on mexico in 1846 .
#
#
#
# 900 4.15847
# TRAIN_SAMPLE:  what is the name of the name of the <UNK> of the year <UNK> ,
# TRAIN_LABEL:  khalifah appointed the governors in the umayyad empire .
#
#
#
# 925 5.13589
# TRAIN_SAMPLE:  madonna was the first woman of the first woman of the movie evita . the
# TRAIN_LABEL:  thein sein became the first myanmar president to visit the white house in 47 years
#
#
#
# 950 4.60437
# TRAIN_SAMPLE:  what is the name of the people of the people were the people of the
# TRAIN_LABEL:  <UNK> observations were included in the 1981 publication of the book of mormon .
#
#
#
# 975 5.1064
# TRAIN_SAMPLE:  the <UNK> was the first of the first of the <UNK> . the <UNK> .
# TRAIN_LABEL:  an outside foundation supplied hayek 's salary .
#
#
#
# 1000 4.22671
# TRAIN_SAMPLE:  senators comprised the soviet union . the soviet union . the soviet union . the
# TRAIN_LABEL:  antoine galland was the first westerner to translate one thousand and one nights .
#
#
#
# 1025 4.12235
# TRAIN_SAMPLE:  <UNK> did the bronx . the bronx of the city . the city . the
# TRAIN_LABEL:  clésinger sculpted chopin 's tombstone .
#
#
#
# 1050 4.44762
# TRAIN_SAMPLE:  what is the name of the name of the <UNK> of the <UNK> of the
# TRAIN_LABEL:  linda woodhead states that christian believers agree that jesus has a unique significance .
#
#
#
# 1075 4.59579
# TRAIN_SAMPLE:  the <UNK> was the first person of the times of the times . the times
# TRAIN_LABEL:  an ethnic group inhabiting india and pakistan are the siddi .
#
#
#
# 1100 4.16564
# TRAIN_SAMPLE:  what is the name of the <UNK> of the <UNK> of the <UNK> of the
# TRAIN_LABEL:  saadia marciano led the israeli black panthers .
#
#
#
# 1125 3.80264
# TRAIN_SAMPLE:  the aztecs was the first person of the the of the greek volleyball . the
# TRAIN_LABEL:  spanish conquistadors brought catholicism into new mexico .
#
#
#
# 1150 4.32587
# TRAIN_SAMPLE:  the soviet union stopped the military military of the soviet union . the soviet union
# TRAIN_LABEL:  some child work as guides for touristsm .
#
#
#
# 1175 3.82562
# TRAIN_SAMPLE:  the national government did the nec of the mandolin . . . . . .
# TRAIN_LABEL:  daimyo were most samurais ' lords .
#
#
#
# 1200 5.06621
# TRAIN_SAMPLE:  the armenian group the armenian group the quran . the quran . the quran .
# TRAIN_LABEL:  since <UNK> , manchester city won the title in the 2011–12 season , becoming the
#
#
#
# 1225 4.76334
# TRAIN_SAMPLE:  <UNK> was the leader of the bronx . the bronx . . . . .
# TRAIN_LABEL:  max scheler did waldemar gurian receive his tutelage under while seeking his doctorate .
#
#
#
# 1250 4.37653
# TRAIN_SAMPLE:  the government of the united states states states states states states states states states states
# TRAIN_LABEL:  james madison wrote that the legislative branch was the predominate branch of government .
#
#
#
# 1275 4.37766
# TRAIN_SAMPLE:  the united of the united states the first the first of the first country .
# TRAIN_LABEL:  the governor of zhejiang is the highest-ranking official in the people 's government of zhejiang
#
#
#
# 1300 4.44722
# TRAIN_SAMPLE:  the united states states states states states states states states states states states states states
# TRAIN_LABEL:  enrico fermi led the team that discovered that <UNK> uranium with neutrons created beta ray
#
#
#
# 1325 4.11629
# TRAIN_SAMPLE:  the first the first person to the first person of the <UNK> of the <UNK>
# TRAIN_LABEL:  who decides safe levels of <UNK> in cities .
#
#
#
# 1350 3.57189
# TRAIN_SAMPLE:  joseph vi was the first of of the first century century century century century century
# TRAIN_LABEL:  charles pollak invented the first electrolytic capacitor .
#
#
#
# 1375 3.94341
# TRAIN_SAMPLE:  the government of the <UNK> of the <UNK> of the <UNK> . the <UNK> .
# TRAIN_LABEL:  dean <UNK> proposed subspecies be defined by the seventy-five percent rule .
#
#
#
# 1400 3.82253
# TRAIN_SAMPLE:  the <UNK> was the first person of the first person of the roman soldier of
# TRAIN_LABEL:  nazi germany and fascist italy . did imperial japan sign a tripartite pact with .
#
#
#
# 1425 3.92901
# TRAIN_SAMPLE:  the puritans did the witch of the persecution . the holy . the church of
# TRAIN_LABEL:  along with the vice president and ncs head , chairman of the joint chiefs urged
#
#
#
# 1450 4.56222
# TRAIN_SAMPLE:  the flame of the theravada . the theravada church . the church of the church
# TRAIN_LABEL:  nassim nicholas taleb wrote the 2007 book the black swan .
#
#
#
# 1475 3.81807
# TRAIN_SAMPLE:  the united states states nations nations nations nations nations nations nations nations nations nations nations
# TRAIN_LABEL:  hieronim nekanda trepka denounced many nobles .
#
#
#
# 1500 4.40726
# TRAIN_SAMPLE:  the united states states states states states states states states states states states states states
# TRAIN_LABEL:  intel first rolled out pentium processors in 1993 .
#
#
#
# 1525 4.32253
# TRAIN_SAMPLE:  the cubs of the cubs of the nlcs of the election . the cubs .
# TRAIN_LABEL:  kpa did not capture the city of namchonjam .
#
#
#
# 1550 4.1321
# TRAIN_SAMPLE:  the elderly of the tuaregs were the main character of the french revolution . the
# TRAIN_LABEL:  the turks captured the border front of saint nicholas during a night attack .
#
#
#
# 1575 4.44631
# TRAIN_SAMPLE:  the government of the united states states states states states states states states states states
# TRAIN_LABEL:  world health organization <UNK> <UNK> .
#
#
#
# 1600 3.98726
# TRAIN_SAMPLE:  the british did the settlers of the first <UNK> . the <UNK> . the <UNK>
# TRAIN_LABEL:  abū rayhān al-bīrūnī stated that there was no evidence to rule out a vacuum .
#
#
#
# 1625 3.46333
# TRAIN_SAMPLE:  the qing was the first mosaic of the mosaic of the mosaic . . .
# TRAIN_LABEL:  <UNK> body and blood is considered present in holy communion .
#
#
#
# 1650 4.10421
# TRAIN_SAMPLE:  what does the people of the people of the people of the people of the
# TRAIN_LABEL:  how many people watched the 2010 winter olympics on february 17 as compared to the
#
#
#
# 1675 4.06038
# TRAIN_SAMPLE:  the abbey abbey abbey abbey 's abbey . the abbey . the abbey . the
# TRAIN_LABEL:  shawn vancour argued that the commercialization of classical music was harmful to the music industry
#
#
#
# 1700 3.88589
# TRAIN_SAMPLE:  the united states states states states states states states states states states states states states
# TRAIN_LABEL:  j. edgar hoover was director from 1924 to 1972 .
#
#
#
# 1725 4.45859
# TRAIN_SAMPLE:  the united states the first lodge of the <UNK> of the <UNK> . the mulatto
# TRAIN_LABEL:  professor juan pedro toni is the headmaster of the christian brothers of ireland stella maris
#
#
#
# 1750 3.88291
# TRAIN_SAMPLE:  the british government instructed the sun the sun of the <UNK> . . the <UNK>
# TRAIN_LABEL:  according to paul vi to godm are a man and woman in union with besides
#
#
#
# 1775 3.54087
# TRAIN_SAMPLE:  the hi-los of the <UNK> of the <UNK> . the <UNK> . the <UNK> .
# TRAIN_LABEL:  sirri amer was nominated to the presidency of the officer 's club .
#
#
#
# 1800 3.59855
# TRAIN_SAMPLE:  the first <UNK> was the first the first painter of the first madrasa . the
# TRAIN_LABEL:  dimitrios ioannides lead the coup d'etat attempt .
#
#
#
# 1825 3.99458
# TRAIN_SAMPLE:  the united states states states states states states states states states states states states states
# TRAIN_LABEL:  francisco <UNK> was sent to negotiate a peace treaty with the rebels .
#
#
#
# 1850 4.63954
# TRAIN_SAMPLE:  the ming was the first person of the first the of the . . the
# TRAIN_LABEL:  president of the republic is the head of state of portugal .
#
#
#
# 1875 3.5977
# TRAIN_SAMPLE:  yeltsin was the first person to the first in-flight papal . . . . .
# TRAIN_LABEL:  william the conqueror was the first recorded coronation at the abbey .
#
#
#
# 1900 3.81453
# TRAIN_SAMPLE:  the united states states states states the us of the united states states states states
# TRAIN_LABEL:  along with ledoux , antónio damásio was a notable neurological brain researcher .
#
#
#
# 1925 3.49258
# TRAIN_SAMPLE:  the united states states the united states volunteers in the united states states states states
# TRAIN_LABEL:  the seleucid empire was mostly dominated by greco-macedonian political <UNK> .
#
#
#
# 1950 3.78946
# TRAIN_SAMPLE:  the british government instructed the sun <UNK> . the <UNK> . the <UNK> . the
# TRAIN_LABEL:  gutenberg invented the movable printing press .
#
#
#
# 1975 3.33683
# TRAIN_SAMPLE:  the <UNK> did the sun <UNK> . the <UNK> . the <UNK> . the <UNK>
# TRAIN_LABEL:  jean-jacques rousseau was a french <UNK> that celebrated the virtues of nature .
#
#
#
# 2000 3.92754
# TRAIN_SAMPLE:  the vinča was the first permanent of the ottoman empire . the ottoman empire .
# TRAIN_LABEL:  bowne was an exponent of so-called `` boston personalism '' .
#
#
#
# 2025 4.20989
# TRAIN_SAMPLE:  the united states states states states states states states states states states states states states
# TRAIN_LABEL:  the sumerians were a non-semitic caucasoid people .
#
#
#
# 2050 3.57032
# TRAIN_SAMPLE:  the ming abolished the ming dynasty dynasty . tibet . the ming dynasty . tibet
# TRAIN_LABEL:  cea published the map of the earthquakes intensity .
#
#
#
# 2075 3.33566
# TRAIN_SAMPLE:  john lofting was the first person to the first person to the first in-flight .
# TRAIN_LABEL:  joshua slocum arrived in jamestown during their solo round the world voyage .
#
#
#
# 2100 3.79612
# TRAIN_SAMPLE:  the united states the first <UNK> of the <UNK> . the <UNK> . . the
# TRAIN_LABEL:  díaz stated that mexico was ready for a democracy and that he would step down
#
#
#
# 2125 3.65748
# TRAIN_SAMPLE:  the british dismantled the the <UNK> cableway . the palace . . . . .
# TRAIN_LABEL:  heraclius was the byzantine leader at the battle of yarmouk .
#
#
#
# 2150 3.91887
# TRAIN_SAMPLE:  the british government the the government of the government of the government of the government
# TRAIN_LABEL:  are there any groups international humanitarian non-governmental organisations ( ngos ) are able to effectively
#
#
#
# 2175 3.5296
# TRAIN_SAMPLE:  the british crown of the british crown of the british crown of the british crown
# TRAIN_LABEL:  rca victor released the first commercial long play discs .
#
#
#
# 2200 4.18188
# TRAIN_SAMPLE:  the first person of the ottoman empire was the first ottoman empire the ottoman empire
# TRAIN_LABEL:  which gunnar myrdalm did hayek share a nobel prize .
#
#
#
# 2225 3.81999
# TRAIN_SAMPLE:  the tribunes was the first president of the premier league . the premier league .
# TRAIN_LABEL:  ibn al-nafis theorized about pulmonary circulation .
#
#
#
# 2250 3.45979
# TRAIN_SAMPLE:  <UNK> luhrmann was the first of the <UNK> of the <UNK> . . . .
# TRAIN_LABEL:  chopin 's nocturnes were more structured than field .
#
#
#
# 2275 3.74235
# TRAIN_SAMPLE:  the supreme court court court court chamber judicial . the monarchm . the monarchm .
# TRAIN_LABEL:  doug morris joined the ceo of epic records in becoming the ceo of sony music
#
#
#
# 2300 4.04921
# TRAIN_SAMPLE:  the united states , the united states , the united states , the united states
# TRAIN_LABEL:  activist bob maza said the aboriginal people started to embrace their ancestry .
#
#
#
# 2325 3.4742
# TRAIN_SAMPLE:  what is the name of the <UNK> was the first person of the of the
# TRAIN_LABEL:  emperor caracalla gave jews the right to full roman citizenship .
#
#
#
# 2350 3.00644
# TRAIN_SAMPLE:  the huns was the first person of the first century century century . the first
# TRAIN_LABEL:  richard dawkins proposes the concept of the `` survival machine . ''
#
#
#
# 2375 3.83691
# TRAIN_SAMPLE:  the <UNK> of the <UNK> of the <UNK> . the <UNK> . the <UNK> .
# TRAIN_LABEL:  what do some feel may happen if child labour products were completely rejected by society
#
#
#
# 2400 3.4676
# TRAIN_SAMPLE:  the government of the republic of the estonia of the estonia . the estonia .
# TRAIN_LABEL:  william scott wilson wrote <UNK> of the samurai ' .
#
#
#
# 2425 3.86702
# TRAIN_SAMPLE:  the british government was the first the first the premier league of the american forces
# TRAIN_LABEL:  the remaining 116 games were retained by sky who paid £760 million-a-year . will show
#
#
#
# 2450 3.8896
# TRAIN_SAMPLE:  the hadza did the ming dynasty titles . the ming dynasty dynasty . the ming
# TRAIN_LABEL:  sean <UNK> starred as daniel ruettiger in the film rudy .
#
#
#
# 2475 3.30663
# TRAIN_SAMPLE:  the united states of the soviet union . the soviet union . the soviet union
# TRAIN_LABEL:  augustus welby northmore pugin wrote the book contrasts .
#
#
#
# 2500 3.62489
# TRAIN_SAMPLE:  the british <UNK> was the first person to the <UNK> . . . . .
# TRAIN_LABEL:  what is the name of the person general sir nicholas houghton is the current chief
#
#
#
# 2525 4.08212
# TRAIN_SAMPLE:  the united states the united states states states states states states states states states states
# TRAIN_LABEL:  the members of the beatles were mbe 's .
#
#
#
# 2550 3.5269
# TRAIN_SAMPLE:  the aztecs was the first of the dikes of the lake . . the lake
# TRAIN_LABEL:  unesco designated the floating gardens as a world heritage site .
#
#
#
# 2575 3.13255
# TRAIN_SAMPLE:  the tsar was the first of the soviet union . the soviet union . the
# TRAIN_LABEL:  aristarchus of samos created the <UNK> model of the solar system .
#
#
#
# 2600 3.07257
# TRAIN_SAMPLE:  the supreme court court court court focuses cases cases cases cases cases cases cases to
# TRAIN_LABEL:  federal government promotes the use of racially categorized data in the united states .
#
#
#
# 2625 3.42674
# TRAIN_SAMPLE:  the british government was the first president of the <UNK> . the <UNK> . the
# TRAIN_LABEL:  liberals suggested that the free trade agreement amounted to an american takeover of canada .
#
#
#
# 2650 3.62404
# TRAIN_SAMPLE:  the puritans were the first inhabitants of the roman of the roman of the roman
# TRAIN_LABEL:  warren did eisenhower nominate for chief justice .
#
#
#
# 2675 3.35517
# TRAIN_SAMPLE:  what is the name of the dog dog of the dog of philippine mythology kimat
# TRAIN_LABEL:  central banks provided funds to encourage lending and restore faith in commercial banks in the
#
#
#
# 2700 3.18598
# TRAIN_SAMPLE:  the british government was the first archivist of the <UNK> . the <UNK> . .
# TRAIN_LABEL:  sigismund ii augustus was the last king of the jagiellonian dynasty .
#
#
#
# 2725 3.43639
# TRAIN_SAMPLE:  the embarked of the french army . the french army . the french army .
# TRAIN_LABEL:  john m. browning designed this cannon .
#
#
#
# 2750 3.95427
# TRAIN_SAMPLE:  the cubs trade trade trade did the cubs of the cubs <UNK> the cubs of
# TRAIN_LABEL:  general macarthur was relieved from his duties as commander in korea .
#
#
#
# 2775 3.7822
# TRAIN_SAMPLE:  the british of the british crown did the tidewater settlers of the gothic street .
# TRAIN_LABEL:  when russia attacked the ottoman empire king otto of greece <UNK> an opportunity to advance
#
#
#
# 2800 3.59908
# TRAIN_SAMPLE:  the national lottery is the largest employer of the city . the <UNK> . .
# TRAIN_LABEL:  the baal shem tov is the founder of hasidic judaism .
#
#
#
# 2825 3.50047
# TRAIN_SAMPLE:  the <UNK> was the first person to the <UNK> of the <UNK> . . .
# TRAIN_LABEL:  modu chanyu was the chieftain of the xiongnu .
#
#
#
# 2850 3.0353
# TRAIN_SAMPLE:  the government of the government of the supreme of the supreme of the supreme of
# TRAIN_LABEL:  john knox was the leader of the scottish reformation .
#
#
#
# 2875 3.76058
# TRAIN_SAMPLE:  the mahayana teachings of the buddha of the saiva . the <UNK> of the <UNK>
# TRAIN_LABEL:  at & t was the third largest sponsor .
#
#
#
# 2900 3.73964
# TRAIN_SAMPLE:  the abbey of the abbey . the abbey of honour . the abbey . the
# TRAIN_LABEL:  procopius wrote about the slavs in byzantine greek in the 6th century .
#
#
#
# 2925 3.67449
# TRAIN_SAMPLE:  the united states states states states states states states states states states states states states
# TRAIN_LABEL:  fbi agents killed filiberto ojeda ríos .
#
#
#
# 2950 3.77601
# TRAIN_SAMPLE:  the united states states states states states states states states states states states states states
# TRAIN_LABEL:  france ( 3.5 % ) is the largest producer in the west , is the
#
#
#
# 2975 3.09334
# TRAIN_SAMPLE:  the british of the british government instructed the sun <UNK> . the new . .
# TRAIN_LABEL:  protestant bible societies was paul vi in favor of cooperating with in the translation of
#
#
#
# 3000 3.43501
# TRAIN_SAMPLE:  the subsequent of the <UNK> was the first of the first of the <UNK> of
# TRAIN_LABEL:  citizens did nasser want more involved in his new political order .
#
#
#
# 3025 3.22276
# TRAIN_SAMPLE:  what was the name of the name of the <UNK> unesco . the <UNK> .
# TRAIN_LABEL:  ioannis kigalas is one of the scholars that fled cyprus during troubled times .
#
#
#
# 3050 3.37486
# TRAIN_SAMPLE:  the supreme court court the supreme court the ruling of the supreme court . the
# TRAIN_LABEL:  inca are the highland quichuas primarily descended from .
#
#
#
# 3075 3.83804
# TRAIN_SAMPLE:  the government of the the government of the the government of the the government of
# TRAIN_LABEL:  adventurer and poet was luís de camões .
#
#
#
# 3100 2.96812
# TRAIN_SAMPLE:  the first non of the us of the us of the united nations nations nations
# TRAIN_LABEL:  puritan iconoclasts attacked the abbey .
#
#
#
# 3125 3.66933
# TRAIN_SAMPLE:  the goverment was the first president of the <UNK> . . . the <UNK> .
# TRAIN_LABEL:  pep guardiola did vilanova replace as manager .
#
#
#
# 3150 3.05237
# TRAIN_SAMPLE:  what is the name of the name of the <UNK> warlord was the first the
# TRAIN_LABEL:  artaxias was the first king of artaxiad dynasty of armenia .
#
#
#
# 3175 3.40936
# TRAIN_SAMPLE:  the first the of the most well-known of the most well-known of the most well-known
# TRAIN_LABEL:  pál tomori was the leader of the hungarian army at the battle of mohács .
#
#
#
# 3200 2.75078
# TRAIN_SAMPLE:  the <UNK> did the <UNK> <UNK> . the <UNK> . . the <UNK> . the
# TRAIN_LABEL:  du fu was known as china 's greatest poet and lived in chengdu .
#
#
#
# 3225 3.67612
# TRAIN_SAMPLE:  the <UNK> domain of the the <UNK> . the <UNK> . the <UNK> . the
# TRAIN_LABEL:  friedrich <UNK> <UNK> approach was introduced in germany in the 19th century and is used
#
#
#
# 3250 3.77369
# TRAIN_SAMPLE:  the liberian was the first person of the <UNK> of the <UNK> . . the
# TRAIN_LABEL:  in sumerian society , a city-state 's primary temple oversaw the operation of the first
#
#
#
# 3275 3.39906
# TRAIN_SAMPLE:  the mongols did the yongle emperor claim to build . . . the ming dynasty
# TRAIN_LABEL:  wei hong was the executive vice governor .
#
#
#
# 3300 3.16042
# TRAIN_SAMPLE:  the supreme court the ruling of the united states of the united states , the
# TRAIN_LABEL:  wildcat hma.2 zz377 conducted the first helicopter landing at the airfield .
#
#
#
# 3325 3.11172
# TRAIN_SAMPLE:  the <UNK> was the first president of the <UNK> . . . the <UNK> .
# TRAIN_LABEL:  g. casavantes led the revolt for the northern portion of the state .
#
#
#
# 3350 3.47379
# TRAIN_SAMPLE:  muawiyah i the the of the <UNK> of the <UNK> . the <UNK> . the
# TRAIN_LABEL:  leopold was victoria 's eighth child .
#
#
#
# 3375 3.38003
# TRAIN_SAMPLE:  the british government instructed the the government of the the government of the the of
# TRAIN_LABEL:  historical definitions of 200 ce a jew is dates back to what year .
#
#
#
# 3400 3.01988
# TRAIN_SAMPLE:  the <UNK> did the sun trust . the <UNK> . . . . . .
# TRAIN_LABEL:  rca victor developed the dynagroove format .
#
#
#
# 3425 3.63531
# TRAIN_SAMPLE:  the <UNK> domain of the the <UNK> . the <UNK> . the <UNK> . the
# TRAIN_LABEL:  arthur m. diamond criticizes hayek 's ability to provide specific facts .
#
#
#
# 3450 3.7254
# TRAIN_SAMPLE:  the <UNK> was the first the the first the the of the first the the
# TRAIN_LABEL:  the assyrian empire dominated the area of <UNK> between the 10th century bc to the
#
#
#
# 3475 3.19165
# TRAIN_SAMPLE:  the mongols was the first <UNK> of the first opium . . the <UNK> .
# TRAIN_LABEL:  barbara milewski said that chopin 's familiarity with polish music was more `` urbanised ''
#
#
#
# 3500 3.18889
# TRAIN_SAMPLE:  the soviet union the first the first non of the first non of the first
# TRAIN_LABEL:  james w. maney was an early leader of the city .
#
#
#
# 3525 3.67107
# TRAIN_SAMPLE:  the united states the the country of the <UNK> . the <UNK> . the <UNK>
# TRAIN_LABEL:  stanley morison was the creator of typeface font used by the times .
#
#
#
# 3550 3.4116
# TRAIN_SAMPLE:  the british government was the first president of the united states states states states .
# TRAIN_LABEL:  peter of alexandria could have been one of athanasius 's teachers .
#
#
#
# 3575 2.86405
# TRAIN_SAMPLE:  the <UNK> was the first person of the first person of the <UNK> . .
# TRAIN_LABEL:  queen elizabeth ii is the commonwealth 's monarch .
#
#
#
# 3600 3.56971
# TRAIN_SAMPLE:  the soviet union was the first president of the the of the the of the
# TRAIN_LABEL:  the british crown was north carolina seeking independence from in 1776 .
#
#
#
# 3625 3.07768
# TRAIN_SAMPLE:  the european government is the first largest employer of the european . the new of
# TRAIN_LABEL:  akechi mitsuhide was an example of a disloyal samurai .
#
#
#
# 3650 3.63609
# TRAIN_SAMPLE:  the soviet union did the rcc of the state . the state . the state
# TRAIN_LABEL:  the captain of the title winning team <UNK> the third lion not found on the
#
#
#
# 3675 3.59455
# TRAIN_SAMPLE:  the united states congress , the united states congress . the united states congress .
# TRAIN_LABEL:  luckett and roberson filed a lawsuit over survivor .
#
#
#
# 3700 2.97573
# TRAIN_SAMPLE:  the u.s. states was the first president of the united states of the united states
# TRAIN_LABEL:  frank lloyd wright was instrumental in creating organic architecture .
#
#
#
# 3725 3.10301
# TRAIN_SAMPLE:  the united states congress was the president of the united states of the united states
# TRAIN_LABEL:  henry viii had a wine cellar at the palace of whitehall .
#
#
#
# 3750 3.76637
# TRAIN_SAMPLE:  the french government was the first person of the <UNK> of the <UNK> . the
# TRAIN_LABEL:  thomas hobbes developed some of the fundamentals of european liberal thought .
#
#
#
# 3775 3.60124
# TRAIN_SAMPLE:  the aztecs was the first person of the first person of the <UNK> of the
# TRAIN_LABEL:  the wife of mexican magnate carlos slim is the museo soumaya named after .
#
#
#
# 3800 3.34608
# TRAIN_SAMPLE:  the tsar of the pruth was the first person of the first person of the
# TRAIN_LABEL:  ibn sina was most influential in islamic philosophy .
#
#
#
# 3825 2.64716
# TRAIN_SAMPLE:  the livonian of the first <UNK> <UNK> . the first 3 3 <UNK> , the
# TRAIN_LABEL:  georges-eugène haussmann was napoleon iii 's prefect of the <UNK> .
#
#
#
# 3850 3.22753
# TRAIN_SAMPLE:  the french of the greeks was the first of the first the first the of
# TRAIN_LABEL:  apg published an influential reclassification of the angiosperms in 1998 .
#
#
#
# 3875 3.62372
# TRAIN_SAMPLE:  the puritans were the first of the holy of the roman catholic church . the
# TRAIN_LABEL:  the national civic league gave the bronx an award in 1997 .
#
#
#
# 3900 3.1109
# TRAIN_SAMPLE:  what is the name of the dog of philippine mythology kimat . the <UNK> of
# TRAIN_LABEL:  besides the french and swedish , british else occupied the island .
#
#
#
# 3925 2.83107
# TRAIN_SAMPLE:  the indo-europeans balto-slavic remained the migrations of the migrations . the the of the <UNK>
# TRAIN_LABEL:  children inherited polish nobility from noble mother and <UNK> .
#
#
#
# 3950 3.23022
# TRAIN_SAMPLE:  the <UNK> did the first non-english of the roman emperor the roman emperor . the
# TRAIN_LABEL:  as of 1910 , krupp , erhardt , vickers maxim , and schneider had published
#
#
#
# 3975 3.72266
# TRAIN_SAMPLE:  the cubs easily in the nlcs . the battle of the wabash . the battle
# TRAIN_LABEL:  the un nations pretty much gained and maintained control of the sea .
#
#
#
# 4000 3.21216
# TRAIN_SAMPLE:  the british government instructed the the government of the the sun <UNK> . . .
# TRAIN_LABEL:  the newspapers demanded drastic reforms after the war .
#
#
#
# 4025 3.30079
# TRAIN_SAMPLE:  the <UNK> domain of the <UNK> <UNK> . the <UNK> . <UNK> . the <UNK>
# TRAIN_LABEL:  attributes of god in islam , and the thirteen attributes of mercy in judaism does
#
#
#
# 4050 3.48202
# TRAIN_SAMPLE:  the <UNK> was siouxsie . the first . . . . the 19th century .
# TRAIN_LABEL:  empress dowager dou was prevented from leaving their house .
#
#
#
# 4075 2.83898
# TRAIN_SAMPLE:  the <UNK> did the vestal answer to the the <UNK> . . the <UNK> .
# TRAIN_LABEL:  calvin was an early leader in the reformed churches .
#
#
#
# 4100 3.5049
# TRAIN_SAMPLE:  the mahayana teachings the buddha of the buddha . the buddha . the buddha .
# TRAIN_LABEL:  linnaeus published systema naturae .
#
#
#
# 4125 3.27965
# TRAIN_SAMPLE:  the abbey was the first person to the first non-english of the roman . .
# TRAIN_LABEL:  an uncertain relationship was held between the slavs and the veneti .
#
#
#
# 4150 3.3673
# TRAIN_SAMPLE:  the united states the nibrs . the french . . the <UNK> . the <UNK>
# TRAIN_LABEL:  explorer matthew flinders was credited with popularizing the use of name terra australis to australia
#
#
#
# 4175 3.14642
# TRAIN_SAMPLE:  what is the name of the <UNK> <UNK> <UNK> was the first the first person
# TRAIN_LABEL:  afrikaans speakers has a more difficult time understanding the other 's language : dutch speakers
#
#
#
# 4200 2.90492
# TRAIN_SAMPLE:  the <UNK> amistad was the first person of the large of the <UNK> of the
# TRAIN_LABEL:  the council , under paul vi , decided <UNK> could make decisions independently of rome
#
#
#
# 4225 2.95468
# TRAIN_SAMPLE:  what is the name of the actor chesney snow was the first person of the
# TRAIN_LABEL:  king saud tried to assassinate nasser .
#
#
#
# 4250 2.76025
# TRAIN_SAMPLE:  the <UNK> was siouxsie . . the 19th century . the pennsylvania . . .
# TRAIN_LABEL:  richard d. zanuck and david brown made spielberg the <UNK> ' director .
#
#
#
# 4275 2.91524
# TRAIN_SAMPLE:  the <UNK> was the first person to the the of the the of the <UNK>
# TRAIN_LABEL:  hatshepsut , thutmose iii , <UNK> and his wife nefertiti , tutankhamun and ramesses ii
#
#
#
# 4300 3.63974
# TRAIN_SAMPLE:  the government of the the <UNK> <UNK> the the <UNK> . the <UNK> . the
# TRAIN_LABEL:  bob dylan and johnny cash did kanye study in order to develop his lyrical skills
#
#
#
# 4325 2.92677
# TRAIN_SAMPLE:  the first of the the of the <UNK> <UNK> was the first person to the
# TRAIN_LABEL:  oliver cromwell began <UNK> national figures in the abbey starting with admiral robert <UNK> .
#
#
#
# 4350 3.46699
# TRAIN_SAMPLE:  the united states was the first of the <UNK> . the <UNK> . the <UNK>
# TRAIN_LABEL:  josep guardiola is the record holder for most trophy wins as coach of barcelona .
#
#
#
# 4375 2.8613
# TRAIN_SAMPLE:  the mathematician euclid was the first person to the the of the the of the
# TRAIN_LABEL:  apollodotus i was the first indo-greek king apollodotus i did not rule from bactria .
#
#
#
# 4400 3.31619
# TRAIN_SAMPLE:  the of the british government instructed the the government of the sun . . .
# TRAIN_LABEL:  debbie dingell represents the congress in ann arbor .
#
#
#
# 4425 2.94859
# TRAIN_SAMPLE:  the <UNK> did the the of the <UNK> . the <UNK> . . the <UNK>
# TRAIN_LABEL:  thomas edison electrified detroit .
#
#
#
# 4450 3.39657
# TRAIN_SAMPLE:  the <UNK> domain of topos . the alhazen . the first <UNK> . the first
# TRAIN_LABEL:  andrew johnson was elected vice president of the united states in 1864 .
#
#
#
# 4475 3.26199
# TRAIN_SAMPLE:  the <UNK> was the first the the of the <UNK> of the <UNK> . the
# TRAIN_LABEL:  besides children , adults can take <UNK> classes .
#
#
#
# 4500 3.22666
# TRAIN_SAMPLE:  the mongols did the ming dynasty gelug . the ming dynasty dynasty dynasty . the
# TRAIN_LABEL:  news agency xinhua set up an online site to focus on blind spots in recovery
#
#
#
# 4525 2.74066
# TRAIN_SAMPLE:  the soviet union was the first president of the the soviet union . the first
# TRAIN_LABEL:  henry cavendish first recognized that hydrogen was a discrete substance .
#
#
#
# 4550 2.93867
# TRAIN_SAMPLE:  the united states the united states states the us of the united states . the
# TRAIN_LABEL:  the city manages houston 's green spaces .
#
#
#
# 4575 3.21626
# TRAIN_SAMPLE:  the french army of the french army defending the french . the french army .
# TRAIN_LABEL:  napoleon iii did orsini try to assassinate .
#
#
#
# 4600 3.18933
# TRAIN_SAMPLE:  the first <UNK> was the first person of the <UNK> of the <UNK> . the
# TRAIN_LABEL:  mohamed ali pasha was ruler of egypt in the 1820s .
#
#
#
# 4625 2.99129
# TRAIN_SAMPLE:  the <UNK> did the sun say of the <UNK> . the <UNK> . the <UNK>
# TRAIN_LABEL:  jack <UNK> set the most recent sales record of vinyl records since 1991 .
#
#
#
# 4650 3.12307
# TRAIN_SAMPLE:  the <UNK> domain of the <UNK> . the <UNK> of the <UNK> . the <UNK>
# TRAIN_LABEL:  what term do those neoliberalism disagree with hayek use to describe his ideals .
#
#
#
# 4675 3.53719
# TRAIN_SAMPLE:  the <UNK> was the first the the the of the <UNK> of the cigarette-rolling .
# TRAIN_LABEL:  mohammad ali shah was defeated and forced to abdicate at the end of the iranian
#
#
#
# 4700 3.02259
# TRAIN_SAMPLE:  the mongols did the ming chinese chinese chinese chinese chinese chinese chinese chinese chinese chinese
# TRAIN_LABEL:  the khitan ruled the liao dynasty .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-cf71f0649813> in <module>()
#      42             dropout_rate: TRAIN_KEEP_PROB
#      43         }
# ---> 44         _, bl, summary = sess.run([train_step, loss, merged], feed_dict=feed_dict)
#      45         #summary_writer.add_summary(summary, i)
#      46         if i % PRINT_EVERY == 0:
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     767                          run_metadata_ptr)
#     768       if run_metadata:
# --> 769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#     770         run_metadata.ParseFromString(compat.as_bytes(proto_data))
#     771     finally:
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     965                              feed_dict_string, options, run_metadata)
#     966     else:
# --> 967       results = []
#     968     return fetch_handler.build_results(self, results)
#     969
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1015                            target_list, options, run_metadata)
#    1016     else:
# -> 1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#    1018                            fetch_list)
#    1019
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1022       return fn(*args)
#    1023     except errors.OpError as e:
# -> 1024       message = compat.as_text(e.message)
#    1025       m = BaseSession._NODEDEF_NAME_RE.search(message)
#    1026       node_def = None
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1004                                  status, run_metadata)
#    1005
# -> 1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#    1007       if target_list:
#    1008         raise RuntimeError('partial_run() requires empty target_list.')
#
# KeyboardInterrupt:
